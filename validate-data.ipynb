# %%
from IPython import display
from IPython.display import Audio, Image

# %%
from database import Database

# %%
db = Database()

# %%
for rowid in range(120, 500, 10):
    rowid, image, audio, *_ = db.get_captcha(rowid).fetchone()
    display.clear_output()
    display.display(Image(image))    
    display.display(Audio(audio, autoplay=True))
    time.sleep(4)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-8081e3647f82> in <module>()
#       4     display.display(Image(image))
#       5     display.display(Audio(audio, autoplay=True))
# ----> 6     time.sleep(4)
#
# KeyboardInterrupt:
